# %%
import lightkurve as lk

# %%
lc=lk.search_lightcurve('Pi Men C')[0].download()

# %%
lc
# Out:
# <TessLightCurve length=18279 LABEL="TIC 261136679" SECTOR=1 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux         flux_err       timecorr    cadenceno  ... mom_centr1_err mom_centr2 mom_centr2_err   pos_corr1      pos_corr2
#                     electron / s   electron / s        d                   ...      pix          pix          pix            pix            pix
#        Time           float32        float32        float32       int32    ...    float32      float64      float32        float32        float32
# ------------------ -------------- -------------- -------------- ---------- ... -------------- ---------- -------------- -------------- --------------
# 1325.2969604950604  1.4641956e+06  1.3036719e+02  1.2319778e-03      70445 ...  8.4099076e-05  260.67540  1.3968609e-04  9.0913408e-02 -7.2966635e-02
# 1325.2983493645327  1.4643365e+06  1.3035809e+02  1.2319590e-03      70446 ...  8.4054744e-05  260.63392  1.3961994e-04  6.2022530e-02 -1.0871942e-01
# ...
